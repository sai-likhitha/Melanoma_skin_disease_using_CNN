# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pathlib
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180
epochs=20

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
#read dataset
pics_dataset=tf.keras.utils.image_dataset_from_directory(data_dir_train,labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    batch_size=32,
    image_size=(img_height,img_width),
    seed=123)
# Out:
# Found 2239 files belonging to 9 classes.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(img_height,img_width), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(img_height,img_width), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
### your code goes here, you can use training or validation data to visuali
import matplotlib.pyplot as plt
label=pics_dataset.class_names
import matplotlib.pyplot as plt
#q=mel_dataset.class_names
index=1
label_dict = {key: 0 for key in label}
plt.figure(figsize=(10,10))
for images,labels in pics_dataset:
    label1=labels[0]
    class_index=tf.argmax(label1)
    if(label_dict[label[class_index]]==0):
        image=images[0]
        plt.subplot(3,3,index)
        plt.imshow(image.numpy().astype("uint8"))
        plt.title(label[class_index])
        index=index+1
        label_dict[label[class_index]]+=1
plt.show()
### your code goes here, you can use training or validation data to visualize
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-8ebdd4f32a38> in <cell line: 9>()
#       7 label_dict = {key: 0 for key in label}
#       8 plt.figure(figsize=(10,10))
# ----> 9 for images,labels in pics_dataset:
#      10     label1=labels[0]
#      11     class_index=tf.argmax(label1)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     807   def __next__(self):
#     808     try:
# --> 809       return self._next_internal()
#     810     except errors.OutOfRangeError:
#     811       raise StopIteration
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     770     # to communicate that there is no more data to iterate over.
#     771     with context.execution_mode(context.SYNC):
# --> 772       ret = gen_dataset_ops.iterator_get_next(
#     773           self._iterator_resource,
#     774           output_types=self._flat_output_types,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    3021   if tld.is_eager:
#    3022     try:
# -> 3023       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3024         _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3025         "output_shapes", output_shapes)
#
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7f26784f2830>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 101, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
# Create a Sequential model
Model= Sequential()

# Normalize pixel values between (0, 1) using Rescaling
Model.add(layers.experimental.preprocessing.Rescaling(scale=1./255,input_shape=(180,180,3)))

# Add Convolutional and Pooling Layers

Model.add(Conv2D(32,(3,3),activation='relu')) #--> remove padding
Model.add(MaxPooling2D(pool_size=(2, 2)))
Model.add(Conv2D(64,(3,3),activation='relu'))
Model.add(MaxPooling2D(pool_size=(2, 2)))
Model.add(Conv2D(64,(3,3),activation='relu'))
Model.add(MaxPooling2D(pool_size=(2, 2)))
Model.add(Conv2D(128,(3,3),activation='relu'))
Model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten layer to transition from convolutional to densely connected layers
Model.add(layers.Flatten())

# Dense layers for classification
Model.add(layers.Dense(155,activation='relu'))
Model.add(layers.Dense(len(pics_dataset.class_names),activation='softmax'))

#To summary the model
Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 9, 9, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 155)               1607195
#
#  dense_1 (Dense)             (None, 9)                 1404
#
# =================================================================
# Total params: 1738775 (6.63 MB)
# Trainable params: 1738775 (6.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
Model.compile(optimizer="Adam",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %%
# View the summary of all layers
Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 89, 89, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 9, 9, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 155)               1607195
#
#  dense_1 (Dense)             (None, 9)                 1404
#
# =================================================================
# Total params: 1738775 (6.63 MB)
# Trainable params: 1738775 (6.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# epochs = 20
# history = Model.fit(
#   train_ds,
#   validation_data=val_ds,
#   epochs=epochs
# )

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
history = Model.fit(train_ds, validation_data=val_ds, epochs=20)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 180s 2s/step - loss: 1.9827 - accuracy: 0.2467 - val_loss: 1.8843 - val_accuracy: 0.2752
# Epoch 2/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.6856 - accuracy: 0.3951 - val_loss: 1.5644 - val_accuracy: 0.4564
# Epoch 3/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.5027 - accuracy: 0.4576 - val_loss: 1.4343 - val_accuracy: 0.5190
# Epoch 4/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.4434 - accuracy: 0.4950 - val_loss: 1.4265 - val_accuracy: 0.5213
# Epoch 5/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.3641 - accuracy: 0.5206 - val_loss: 1.4130 - val_accuracy: 0.5213
# Epoch 6/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.3751 - accuracy: 0.5257 - val_loss: 1.3965 - val_accuracy: 0.5257
# Epoch 7/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.2987 - accuracy: 0.5396 - val_loss: 1.3914 - val_accuracy: 0.5078
# Epoch 8/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.2751 - accuracy: 0.5536 - val_loss: 1.4309 - val_accuracy: 0.5123
# Epoch 9/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.2540 - accuracy: 0.5458 - val_loss: 1.3904 - val_accuracy: 0.5168
# Epoch 10/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.2561 - accuracy: 0.5592 - val_loss: 1.3491 - val_accuracy: 0.5503
# Epoch 11/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.1635 - accuracy: 0.5904 - val_loss: 1.5366 - val_accuracy: 0.4810
# Epoch 12/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.1755 - accuracy: 0.5798 - val_loss: 1.5392 - val_accuracy: 0.5213
# Epoch 13/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.1238 - accuracy: 0.5910 - val_loss: 1.3879 - val_accuracy: 0.5324
# Epoch 14/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.0564 - accuracy: 0.6060 - val_loss: 1.4130 - val_accuracy: 0.5347
# Epoch 15/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.0106 - accuracy: 0.6356 - val_loss: 1.4851 - val_accuracy: 0.5078
# Epoch 16/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.9120 - accuracy: 0.6607 - val_loss: 1.5227 - val_accuracy: 0.5391
# Epoch 17/20
# 56/56 [==============================] - 2s 35ms/step - loss: 0.8929 - accuracy: 0.6713 - val_loss: 1.7254 - val_accuracy: 0.5168
# Epoch 18/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.8933 - accuracy: 0.6791 - val_loss: 1.6718 - val_accuracy: 0.5436
# Epoch 19/20
# 56/56 [==============================] - 2s 32ms/step - loss: 0.7569 - accuracy: 0.7115 - val_loss: 1.7294 - val_accuracy: 0.5414
# Epoch 20/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.7086 - accuracy: 0.7461 - val_loss: 1.9177 - val_accuracy: 0.4944

# %% [markdown]
# ### Visualizing training results

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
train_ds_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("vertical",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomFlip("horizontal",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
   layers.experimental.preprocessing.RandomRotation(0.5),
  ]
)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = train_ds_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

model_after_augmentation = Sequential([
  train_ds_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.5),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(155, 3, padding='same', activation='relu'),
  layers.Flatten(),
  layers.Dense(155, activation='relu'),
  layers.Dropout(0.4),
  layers.Dense(len(pics_dataset.class_names))
])
model_after_augmentation.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 90, 90, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 45, 45, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 45, 45, 64)        36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 22, 22, 128)       73856
#
#  max_pooling2d_7 (MaxPoolin  (None, 11, 11, 128)       0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 11, 11, 155)       178715
#
#  flatten_1 (Flatten)         (None, 18755)             0
#
#  dense_2 (Dense)             (None, 155)               2907180
#
#  dropout_1 (Dropout)         (None, 155)               0
#
#  dense_3 (Dense)             (None, 9)                 1404
#
# =================================================================
# Total params: 3217475 (12.27 MB)
# Trainable params: 3217475 (12.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
model_after_augmentation.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
epochs = 20
history1 = model_after_augmentation.fit(train_ds, validation_data=val_ds, epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 11s 72ms/step - loss: 4.7908 - accuracy: 0.0731 - val_loss: 2.2691 - val_accuracy: 0.1924
# Epoch 2/20
# 56/56 [==============================] - 3s 60ms/step - loss: 2.4958 - accuracy: 0.1702 - val_loss: 2.0487 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 4s 66ms/step - loss: 2.2817 - accuracy: 0.1763 - val_loss: 2.0520 - val_accuracy: 0.1924
# Epoch 4/20
# 56/56 [==============================] - 4s 63ms/step - loss: 2.2181 - accuracy: 0.1959 - val_loss: 2.0298 - val_accuracy: 0.1924
# Epoch 5/20
# 56/56 [==============================] - 4s 64ms/step - loss: 2.2058 - accuracy: 0.1970 - val_loss: 2.0288 - val_accuracy: 0.2058
# Epoch 6/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.2341 - accuracy: 0.1892 - val_loss: 2.0352 - val_accuracy: 0.2058
# Epoch 7/20
# 56/56 [==============================] - 4s 63ms/step - loss: 2.1453 - accuracy: 0.2037 - val_loss: 2.0358 - val_accuracy: 0.2058
# Epoch 8/20
# 56/56 [==============================] - 3s 62ms/step - loss: 2.0902 - accuracy: 0.1869 - val_loss: 2.0316 - val_accuracy: 0.1946
# Epoch 9/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.1096 - accuracy: 0.2076 - val_loss: 2.0327 - val_accuracy: 0.1924
# Epoch 10/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0841 - accuracy: 0.1936 - val_loss: 2.0242 - val_accuracy: 0.1924
# Epoch 11/20
# 56/56 [==============================] - 4s 64ms/step - loss: 2.1179 - accuracy: 0.1953 - val_loss: 2.0398 - val_accuracy: 0.2349
# Epoch 12/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.1219 - accuracy: 0.2193 - val_loss: 2.0258 - val_accuracy: 0.2058
# Epoch 13/20
# 56/56 [==============================] - 3s 60ms/step - loss: 2.0893 - accuracy: 0.2126 - val_loss: 2.0259 - val_accuracy: 0.2058
# Epoch 14/20
# 56/56 [==============================] - 3s 62ms/step - loss: 2.0808 - accuracy: 0.1948 - val_loss: 2.0276 - val_accuracy: 0.2058
# Epoch 15/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0543 - accuracy: 0.1836 - val_loss: 2.0232 - val_accuracy: 0.2058
# Epoch 16/20
# 56/56 [==============================] - 3s 60ms/step - loss: 2.0540 - accuracy: 0.2031 - val_loss: 2.0226 - val_accuracy: 0.2081
# Epoch 17/20
# 56/56 [==============================] - 3s 58ms/step - loss: 2.0451 - accuracy: 0.2031 - val_loss: 2.0181 - val_accuracy: 0.2036
# Epoch 18/20
# 56/56 [==============================] - 3s 58ms/step - loss: 3.3336 - accuracy: 0.1881 - val_loss: 2.7150 - val_accuracy: 0.0872
# Epoch 19/20
# 56/56 [==============================] - 3s 61ms/step - loss: 2.8525 - accuracy: 0.0608 - val_loss: 2.5081 - val_accuracy: 0.0403
# Epoch 20/20
# 56/56 [==============================] - 4s 63ms/step - loss: 2.5379 - accuracy: 0.0463 - val_loss: 2.4449 - val_accuracy: 0.0403

# %% [markdown]
# ### Visualizing the results

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']

loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
import os

def class_count(dir):

    #count number of image in each classes
    count= []
    for path in pathlib.Path(dir).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    #name of the classes
    sub_directory = [name for name in os.listdir(dir)
                    if os.path.isdir(os.path.join(dir, name))]

    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'Num of images'])

df = class_count(data_dir_train)
df
# Out:
#                         Class  Num of images
# 0              dermatofibroma             95
# 1  pigmented benign keratosis            462
# 2           actinic keratosis            114
# 3             vascular lesion            139
# 4        basal cell carcinoma            376
# 5        seborrheic keratosis             77
# 6                    melanoma            438
# 7     squamous cell carcinoma            181
# 8                       nevus            357

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# seborrheic keratosis	 class  has 77 num of images.This is the least one.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
import Augmentor
from Augmentor import Pipeline
path_to_training_dataset= "/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
print(pics_dataset.class_names)
for i in pics_dataset.class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i,path_to_training_dataset+ i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2642982710>: 100%|██████████| 500/500 [00:20<00:00, 23.93 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F26429D3790>: 100%|██████████| 500/500 [00:24<00:00, 20.70 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2642945A50>: 100%|██████████| 500/500 [00:23<00:00, 21.57 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=919x802 at 0x7F2642DF2CB0>: 100%|██████████| 500/500 [01:22<00:00,  6.06 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus.
# Processing <PIL.Image.Image image mode=RGB size=962x723 at 0x7F2642C71540>: 100%|██████████| 500/500 [01:20<00:00,  6.18 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2642803DC0>: 100%|██████████| 500/500 [00:18<00:00, 27.31 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F2642944AC0>: 100%|██████████| 500/500 [00:41<00:00, 11.94 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2642B77940>: 100%|██████████| 500/500 [00:19<00:00, 25.58 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2642985150>: 100%|██████████| 500/500 [00:20<00:00, 24.45 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
import glob
from glob import *
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 6739

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
train_ds_new = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  label_mode="categorical",
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds_new = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  label_mode='categorical',
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
#create the model
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

Model3= Sequential()
Model3.add(layers.experimental.preprocessing.Rescaling(scale=1./255,input_shape=(180,180,3)))
Model3.add(Conv2D(32,(3,3),activation='relu')) #--> remove padding
Model3.add(MaxPooling2D(pool_size=(2, 2)))
Model3.add(Conv2D(64,(3,3),activation='relu'))
Model3.add(MaxPooling2D(pool_size=(2, 2)))
Model3.add(Conv2D(64,(3,3),activation='relu'))
Model3.add(MaxPooling2D(pool_size=(2, 2)))
Model3.add(layers.Dropout(0.48))
Model3.add(Conv2D(128,(3,3),activation='relu'))
Model3.add(MaxPooling2D(pool_size=(2, 2)))
Model3.add(layers.Flatten())
Model3.add(layers.Dense(175,activation='relu'))
Model3.add(layers.Dropout(0.42))
Model3.add(layers.Dense(len(pics_dataset.class_names),activation='softmax'))
Model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_8 (MaxPoolin  (None, 89, 89, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_9 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 41, 41, 64)        36928
#
#  max_pooling2d_10 (MaxPooli  (None, 20, 20, 64)        0
#  ng2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 64)        0
#
#  conv2d_12 (Conv2D)          (None, 18, 18, 128)       73856
#
#  max_pooling2d_11 (MaxPooli  (None, 9, 9, 128)         0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 10368)             0
#
#  dense_4 (Dense)             (None, 175)               1814575
#
#  dropout_3 (Dropout)         (None, 175)               0
#
#  dense_5 (Dense)             (None, 9)                 1584
#
# =================================================================
# Total params: 1946335 (7.42 MB)
# Trainable params: 1946335 (7.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
#compile the model
Model3.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# ####   Train your model

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds1 = train_ds_new.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds1 = val_ds_new.cache().prefetch(buffer_size=AUTOTUNE)
checkpoint = ModelCheckpoint("Model3.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
earlystop = EarlyStopping(monitor="val_loss",patience=5,mode="auto",verbose=1)

# %%
epochs = 36
history3 = Model3.fit(train_ds_new, validation_data=val_ds_new, epochs=epochs,callbacks=[checkpoint])
# Out:
# Epoch 1/36
# 169/169 [==============================] - ETA: 0s - loss: 2.1933 - accuracy: 0.1430
# Epoch 1: val_accuracy improved from -inf to 0.21010, saving model to Model3.h5
# 169/169 [==============================] - 45s 244ms/step - loss: 2.1933 - accuracy: 0.1430 - val_loss: 1.9469 - val_accuracy: 0.2101
# Epoch 2/36
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 168/169 [============================>.] - ETA: 0s - loss: 1.8389 - accuracy: 0.2982
# Epoch 2: val_accuracy improved from 0.21010 to 0.39866, saving model to Model3.h5
# 169/169 [==============================] - 35s 204ms/step - loss: 1.8382 - accuracy: 0.2984 - val_loss: 1.6589 - val_accuracy: 0.3987
# Epoch 3/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.6361 - accuracy: 0.3778
# Epoch 3: val_accuracy improved from 0.39866 to 0.44395, saving model to Model3.h5
# 169/169 [==============================] - 36s 210ms/step - loss: 1.6360 - accuracy: 0.3778 - val_loss: 1.4448 - val_accuracy: 0.4439
# Epoch 4/36
# 169/169 [==============================] - ETA: 0s - loss: 1.5490 - accuracy: 0.4058
# Epoch 4: val_accuracy improved from 0.44395 to 0.44915, saving model to Model3.h5
# 169/169 [==============================] - 38s 214ms/step - loss: 1.5490 - accuracy: 0.4058 - val_loss: 1.3922 - val_accuracy: 0.4491
# Epoch 5/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.4639 - accuracy: 0.4295
# Epoch 5: val_accuracy did not improve from 0.44915
# 169/169 [==============================] - 45s 258ms/step - loss: 1.4630 - accuracy: 0.4301 - val_loss: 1.3761 - val_accuracy: 0.4447
# Epoch 6/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.4072 - accuracy: 0.4501
# Epoch 6: val_accuracy improved from 0.44915 to 0.46622, saving model to Model3.h5
# 169/169 [==============================] - 37s 206ms/step - loss: 1.4081 - accuracy: 0.4497 - val_loss: 1.3884 - val_accuracy: 0.4662
# Epoch 7/36
# 169/169 [==============================] - ETA: 0s - loss: 1.3434 - accuracy: 0.4766
# Epoch 7: val_accuracy improved from 0.46622 to 0.55828, saving model to Model3.h5
# 169/169 [==============================] - 36s 210ms/step - loss: 1.3434 - accuracy: 0.4766 - val_loss: 1.2383 - val_accuracy: 0.5583
# Epoch 8/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.2809 - accuracy: 0.5020
# Epoch 8: val_accuracy did not improve from 0.55828
# 169/169 [==============================] - 36s 206ms/step - loss: 1.2802 - accuracy: 0.5022 - val_loss: 1.2015 - val_accuracy: 0.5234
# Epoch 9/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.2535 - accuracy: 0.5175
# Epoch 9: val_accuracy did not improve from 0.55828
# 169/169 [==============================] - 36s 206ms/step - loss: 1.2531 - accuracy: 0.5176 - val_loss: 1.1824 - val_accuracy: 0.5174
# Epoch 10/36
# 169/169 [==============================] - ETA: 0s - loss: 1.1985 - accuracy: 0.5371
# Epoch 10: val_accuracy improved from 0.55828 to 0.59688, saving model to Model3.h5
# 169/169 [==============================] - 36s 206ms/step - loss: 1.1985 - accuracy: 0.5371 - val_loss: 1.0623 - val_accuracy: 0.5969
# Epoch 11/36
# 169/169 [==============================] - ETA: 0s - loss: 1.1255 - accuracy: 0.5590
# Epoch 11: val_accuracy did not improve from 0.59688
# 169/169 [==============================] - 36s 207ms/step - loss: 1.1255 - accuracy: 0.5590 - val_loss: 1.3139 - val_accuracy: 0.5204
# Epoch 12/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.1125 - accuracy: 0.5729
# Epoch 12: val_accuracy improved from 0.59688 to 0.61990, saving model to Model3.h5
# 169/169 [==============================] - 36s 210ms/step - loss: 1.1124 - accuracy: 0.5729 - val_loss: 0.9953 - val_accuracy: 0.6199
# Epoch 13/36
# 168/169 [============================>.] - ETA: 0s - loss: 1.0126 - accuracy: 0.6097
# Epoch 13: val_accuracy did not improve from 0.61990
# 169/169 [==============================] - 37s 211ms/step - loss: 1.0125 - accuracy: 0.6098 - val_loss: 1.2287 - val_accuracy: 0.5256
# Epoch 14/36
# 169/169 [==============================] - ETA: 0s - loss: 0.9916 - accuracy: 0.6129
# Epoch 14: val_accuracy improved from 0.61990 to 0.63697, saving model to Model3.h5
# 169/169 [==============================] - 41s 237ms/step - loss: 0.9916 - accuracy: 0.6129 - val_loss: 0.9433 - val_accuracy: 0.6370
# Epoch 15/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.9373 - accuracy: 0.6362
# Epoch 15: val_accuracy improved from 0.63697 to 0.65776, saving model to Model3.h5
# 169/169 [==============================] - 36s 209ms/step - loss: 0.9381 - accuracy: 0.6359 - val_loss: 0.8991 - val_accuracy: 0.6578
# Epoch 16/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.8704 - accuracy: 0.6590
# Epoch 16: val_accuracy improved from 0.65776 to 0.70230, saving model to Model3.h5
# 169/169 [==============================] - 42s 243ms/step - loss: 0.8698 - accuracy: 0.6593 - val_loss: 0.8208 - val_accuracy: 0.7023
# Epoch 17/36
# 169/169 [==============================] - ETA: 0s - loss: 0.8611 - accuracy: 0.6591
# Epoch 17: val_accuracy did not improve from 0.70230
# 169/169 [==============================] - 43s 248ms/step - loss: 0.8611 - accuracy: 0.6591 - val_loss: 0.8465 - val_accuracy: 0.6748
# Epoch 18/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.8073 - accuracy: 0.6778
# Epoch 18: val_accuracy did not improve from 0.70230
# 169/169 [==============================] - 37s 209ms/step - loss: 0.8074 - accuracy: 0.6779 - val_loss: 1.0268 - val_accuracy: 0.6600
# Epoch 19/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.8181 - accuracy: 0.6832
# Epoch 19: val_accuracy improved from 0.70230 to 0.73200, saving model to Model3.h5
# 169/169 [==============================] - 39s 228ms/step - loss: 0.8180 - accuracy: 0.6836 - val_loss: 0.7530 - val_accuracy: 0.7320
# Epoch 20/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.7179 - accuracy: 0.7251
# Epoch 20: val_accuracy did not improve from 0.73200
# 169/169 [==============================] - 36s 209ms/step - loss: 0.7179 - accuracy: 0.7253 - val_loss: 0.7775 - val_accuracy: 0.7283
# Epoch 21/36
# 169/169 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.7207
# Epoch 21: val_accuracy improved from 0.73200 to 0.73868, saving model to Model3.h5
# 169/169 [==============================] - 40s 226ms/step - loss: 0.6945 - accuracy: 0.7207 - val_loss: 0.7132 - val_accuracy: 0.7387
# Epoch 22/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.6464 - accuracy: 0.7387
# Epoch 22: val_accuracy improved from 0.73868 to 0.76169, saving model to Model3.h5
# 169/169 [==============================] - 36s 207ms/step - loss: 0.6457 - accuracy: 0.7389 - val_loss: 0.6832 - val_accuracy: 0.7617
# Epoch 23/36
# 169/169 [==============================] - ETA: 0s - loss: 0.6674 - accuracy: 0.7385
# Epoch 23: val_accuracy did not improve from 0.76169
# 169/169 [==============================] - 36s 208ms/step - loss: 0.6674 - accuracy: 0.7385 - val_loss: 0.6574 - val_accuracy: 0.7565
# Epoch 24/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.6332 - accuracy: 0.7556
# Epoch 24: val_accuracy did not improve from 0.76169
# 169/169 [==============================] - 36s 208ms/step - loss: 0.6329 - accuracy: 0.7556 - val_loss: 0.6678 - val_accuracy: 0.7595
# Epoch 25/36
# 169/169 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.7452
# Epoch 25: val_accuracy did not improve from 0.76169
# 169/169 [==============================] - 39s 225ms/step - loss: 0.6339 - accuracy: 0.7452 - val_loss: 0.7282 - val_accuracy: 0.7372
# Epoch 26/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.6005 - accuracy: 0.7593
# Epoch 26: val_accuracy improved from 0.76169 to 0.77877, saving model to Model3.h5
# 169/169 [==============================] - 36s 209ms/step - loss: 0.6002 - accuracy: 0.7591 - val_loss: 0.6321 - val_accuracy: 0.7788
# Epoch 27/36
# 169/169 [==============================] - ETA: 0s - loss: 0.5937 - accuracy: 0.7659
# Epoch 27: val_accuracy did not improve from 0.77877
# 169/169 [==============================] - 37s 211ms/step - loss: 0.5937 - accuracy: 0.7659 - val_loss: 0.6437 - val_accuracy: 0.7624
# Epoch 28/36
# 169/169 [==============================] - ETA: 0s - loss: 0.5426 - accuracy: 0.7864
# Epoch 28: val_accuracy improved from 0.77877 to 0.79881, saving model to Model3.h5
# 169/169 [==============================] - 38s 214ms/step - loss: 0.5426 - accuracy: 0.7864 - val_loss: 0.6187 - val_accuracy: 0.7988
# Epoch 29/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.5201 - accuracy: 0.7861
# Epoch 29: val_accuracy did not improve from 0.79881
# 169/169 [==============================] - 36s 209ms/step - loss: 0.5204 - accuracy: 0.7854 - val_loss: 0.8987 - val_accuracy: 0.6993
# Epoch 30/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.5636 - accuracy: 0.7736
# Epoch 30: val_accuracy did not improve from 0.79881
# 169/169 [==============================] - 36s 207ms/step - loss: 0.5636 - accuracy: 0.7734 - val_loss: 0.6179 - val_accuracy: 0.7743
# Epoch 31/36
# 169/169 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.7988
# Epoch 31: val_accuracy improved from 0.79881 to 0.80846, saving model to Model3.h5
# 169/169 [==============================] - 37s 211ms/step - loss: 0.4843 - accuracy: 0.7988 - val_loss: 0.5877 - val_accuracy: 0.8085
# Epoch 32/36
# 169/169 [==============================] - ETA: 0s - loss: 0.4962 - accuracy: 0.8029
# Epoch 32: val_accuracy did not improve from 0.80846
# 169/169 [==============================] - 36s 206ms/step - loss: 0.4962 - accuracy: 0.8029 - val_loss: 0.6861 - val_accuracy: 0.7765
# Epoch 33/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.4658 - accuracy: 0.8145
# Epoch 33: val_accuracy did not improve from 0.80846
# 169/169 [==============================] - 36s 207ms/step - loss: 0.4665 - accuracy: 0.8142 - val_loss: 0.5937 - val_accuracy: 0.8085
# Epoch 34/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.4687 - accuracy: 0.8114
# Epoch 34: val_accuracy improved from 0.80846 to 0.80921, saving model to Model3.h5
# 169/169 [==============================] - 36s 207ms/step - loss: 0.4683 - accuracy: 0.8118 - val_loss: 0.5783 - val_accuracy: 0.8092
# Epoch 35/36
# 169/169 [==============================] - ETA: 0s - loss: 0.7288 - accuracy: 0.7420
# Epoch 35: val_accuracy did not improve from 0.80921
# 169/169 [==============================] - 36s 205ms/step - loss: 0.7288 - accuracy: 0.7420 - val_loss: 0.5992 - val_accuracy: 0.7951
# Epoch 36/36
# 168/169 [============================>.] - ETA: 0s - loss: 0.4633 - accuracy: 0.8185
# Epoch 36: val_accuracy improved from 0.80921 to 0.81143, saving model to Model3.h5
# 169/169 [==============================] - 44s 250ms/step - loss: 0.4627 - accuracy: 0.8188 - val_loss: 0.5712 - val_accuracy: 0.8114

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history3.history['accuracy']
val_acc = history3.history['val_accuracy']

loss = history3.history['loss']
val_loss = history3.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Observations
# - Model has good validation accuracy and low validation loss
# - Difference between Validation Loss and Training Loss is low. Also, Validation Accuracy and Traning accuracy are very close.
# - Model can predict now on unseen dataset with good accuracy

# %% [markdown]
# ##Model Predictions
# Predictions from the created model on Test dataset

# %%
from glob import glob
from tensorflow.keras.preprocessing.image import load_img
import matplotlib.pyplot as plt

# Loading the Test Dataset for model predictions
pics_test_dataset=tf.keras.utils.image_dataset_from_directory(data_dir_test,labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    batch_size=32,
    image_size=(img_height,img_width),
    seed=123)

label_test=pics_test_dataset.class_names


# Class Wise prediction for Test dataset
index=1
label_test_dict = {key: 0 for key in label_test}
plt.figure(figsize=(25,10))
print(label_test_dict)
for images,labels in pics_dataset:
    label1=labels[0]
    class_index=tf.argmax(label1)
    if(label_test_dict[label_test[class_index]]==0):
        image=images[0]
        # Predicting for image from each class
        img = np.expand_dims(image,axis=0)
        pred = Model3.predict(img)
        pred = np.argmax(pred)
        pred_class = label_test[pred]
        plt.subplot(3,3,index)
        plt.imshow(image.numpy().astype("uint8"))
        # Displaying Predicted class of Image in Title along with the actual class of image
        plt.title("Actual: "+label_test[class_index]+" Precdiction: "+pred_class,fontsize=10)
        index=index+1
        label_test_dict[label_test[class_index]]+=1

plt.show()
# Out:
# Found 118 files belonging to 9 classes.
# {'actinic keratosis': 0, 'basal cell carcinoma': 0, 'dermatofibroma': 0, 'melanoma': 0, 'nevus': 0, 'pigmented benign keratosis': 0, 'seborrheic keratosis': 0, 'squamous cell carcinoma': 0, 'vascular lesion': 0}
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step

# %% [markdown]
# ## Observations:
# - Model is able to predict for test dataset, for all 9 classes the predictions are correct.
# - In Above figure,  Title we can see both actual and predicted class names.
# - Class imbalance is not there in dataset now.
#
# - Model is not overfitting, as evident from loss/accuracy metrics. Class rebalance helped in avoiding overfitting.
# - <b>Model Accuracy:</b>
#     - Validation Accuracy: 81.88%
#     - Traning Accuracy: 81.124%
# - <b>Model Loss</b>
#     - Validation Loss: 0.5177
#     - Training Loss: 0.4627
